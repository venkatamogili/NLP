# %%
pip install openai

# %%
from openai import OpenAI

client = OpenAI(api_key="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")

# %%
prompt = "Artificial Intelligence will change the world by"

# %% [markdown]
# :**Controlled vs. Creative: The Role of Temperature**

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}],
    temperature=1,   # try 0.2 vs 1.0 vs 1.5
    max_tokens=50
)

print(response.choices[0].message.content)
# Out:
# Artificial Intelligence (AI) will change the world in several profound and transformative ways:
#
# 1. **Automation of Tasks**: AI will automate routine and repetitive tasks across industries, increasing efficiency and freeing up human workers to focus on more complex and creative activities.

# %% [markdown]
# **Exploring Diversity with Top-p (Nucleus Sampling)**

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}],
    temperature=1.0,
    top_p=0.9,         # try 0.3 vs 0.9
    max_tokens=50
)

print(response.choices[0].message.content)
# Out:
# Artificial Intelligence (AI) is poised to change the world in numerous profound ways across various sectors. Here are some key areas where AI is expected to have a significant impact:
#
# 1. **Healthcare**: AI can analyze vast amounts of medical data, assist

# %% [markdown]
# **FREQUENCY PENALITY**

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}],
    max_tokens=20      # try 20 vs 100
)

print(response.choices[0].message.content)
# Out:
# Artificial Intelligence (AI) is poised to change the world in numerous profound ways. Here are several key

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}],
    frequency_penalty=1.5,   # try 0.0 vs 1.5
    max_tokens=60
)

print(response.choices[0].message.content)
# Out:
# Artificial Intelligence (AI) is set to transform the world in numerous profound ways across various domains. Here are some key areas where AI will have a significant impact:
#
# 1. **Healthcare**: AI can revolutionize diagnostics and treatment by analyzing vast amounts of medical data, improving disease prediction, personalizing patient

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}],
    temperature=0.8,
    top_p=0.9,
    max_tokens=60,
    frequency_penalty=1.2
)

print(response.choices[0].message.content)
# Out:
# Artificial Intelligence (AI) is poised to change the world in numerous transformative ways. Here are several key areas where its impact is particularly significant:
#
# 1. **Healthcare**: AI can enhance diagnostic accuracy, personalize treatment plans, and predict patient outcomes. Machine learning algorithms analyze medical images and patient data more effectively
